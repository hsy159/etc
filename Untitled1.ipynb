# %%
from bs4 import BeautifulSoup
import requests

# %%
def get_page(interest):
    print "fetching " , interest
        
    # your code here (remove 'pass')
    URL = "http://cafe.naver.com/" + interest
    #http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20161004
    head_r = requests.get(URL)
    soup = BeautifulSoup(head_r.text)
#    print soup
    return soup

# %%
interest_temp = '/ArticleList.nhn?search.clubid=15754634&search.menuid=2299&search.boardtype=L'
#get_page(interest_temp)

# %%
from pattern.web import Element
from pattern import web

# %%
from ghost import ghost
#from config import COOKIE_FILE, LOGIN_ID, LOGIN_PW
import urllib2
import cookielib
import Cookie

# %%
class NaverCrawler:
    # 새 크롤러를 만듭니다.
    def __init__(self, id, pw, displayFlag = False):
        # 새 Ghost instance를 만들어서 사용합니다.
        self.ghost = ghost.Session(self,display = displayFlag, wait_timeout = 20)
        self.currentPage = None
        self.login(id, pw)
        self.logger = 

    # 주어진 페이지를 엽니다. 이미 그 페이지에 있으면 그대로 있습니다.
    def openPage(self, url):
        if self.currentPage == url:
            return
        self.ghost.open(url)
        self.ghost.wait_for_page_loaded()
        self.currentPage = url

    # 네이버 로그인을 수행합니다.
    def login(self, id, pw):
        # 네이버 메인 페이지를 엽니다.
        self.openPage('http://www.naver.com')

        # inner frame에 들어있는 로그인 폼에 값을 채워넣고 클릭을 지시합니다.
        # 이부분은 javascript를 활용했습니다.
        self.ghost.evaluate("""
        (function() {        
          var innerDoc = document.getElementById('loginframe').contentWindow.document;
          innerDoc.getElementById('id').value = '%s';
          innerDoc.getElementById('pw').value = '%s';
          innerDoc.getElementsByClassName('btn_login')[0].click();
        })();
        """ % (id, pw), expect_loading = True)

        # 로그인 결과를 기다립니다.
        self.ghost.wait_for_selector('#query')

    def cloneCookieJar(self):
        cookieJar = cookielib.LWPCookieJar()
        self.ghost.save_cookies(cookieJar)
        return cookieJar

    # 네이버 메인 페이지에서 검색을 수행합니다.
    def main_search(self, query):
        # 네이버 메인 페이지를 엽니다.
        self.openPage('http://www.naver.com')

        self.ghost.wait_for_selector('#query')
        self.ghost.fill("#sform", { "query": query })
        self.ghost.fire_on('#sform', 'submit', expect_loading = True)

if __name__ == "__main__":
    crawler = NaverCrawler('061354', 'tjdusslasla12', False)
    cj = crawler.cloneCookieJar()
    cj.save(COOKIE_FILE)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-76558de52e0b> in <module>()
#      49
#      50 if __name__ == "__main__":
# ---> 51     crawler = NaverCrawler('061354', 'tjdusslasla12', False)
#      52     cj = crawler.cloneCookieJar()
#      53     cj.save(COOKIE_FILE)
#
# <ipython-input-42-76558de52e0b> in __init__(self, id, pw, displayFlag)
#       3     def __init__(self, id, pw, displayFlag = False):
#       4         # 새 Ghost instance를 만들어서 사용합니다.
# ----> 5         self.ghost = ghost.Session(self,display = displayFlag, wait_timeout = 20)
#       6         self.currentPage = None
#       7         self.login(id, pw)
#
# ...

# %%
interest_temp = '/ArticleList.nhn?search.clubid=15754634&search.menuid=2299&search.boardtype=L'
#get_page(interest_temp)

# %%
html=get_page(interest_temp)
element = web.Element(html)

print element

#a = html.findAll('a',{'href':'/ArticleRead.nhn?clubid=15754634&page=1&menuid=2299&boardtype=L&articleid=4448269&referrerAllArticles=false'})

#print a
# Out:
# fetching  /ArticleList.nhn?search.clubid=15754634&search.menuid=2299&search.boardtype=L
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta content="noindex, nofollow" name="robots" />
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type" />
# <meta content="requiresActiveX=true" http-equiv="X-UA-Compatible" />
# <title>카페</title>
# <link href="/favicon.ico?2" rel="shortcut icon" type="image/x-icon" />
# <link href="/static/css/main/css/mycafe-common-1459945953000-56089.css" rel="stylesheet" type="text/css" />
# <link href="/static/css/main/css/mycafe-layout-1463630909000-54983.css" rel="stylesheet" type="text/css" />
# <link href="/static/css/main/css/line_sticker-1459945953000-9159.css" rel="stylesheet" type="text/css" />
# <link href="/static/css/main/css/comment-1463630909000-16252.css" rel="stylesheet" type="text/css" />
# ...

# %%
a = html.findAll('div',{'class':'article-board m-tcol-c'})
#b = a.findAll('span',{'class':'aaa'})

print a[0]
# Out:
# <div class="article-board m-tcol-c">
# <form autocomplete="off" name="ArticleList">
# <table border="0" cellpadding="0" cellspacing="0" class="board-box" style="table-layout:fixed">
# <col width="70"></col><col width="*"></col><col width="122"></col><col width="70"></col><col width="42"></col>
# <col width="49"></col>
# <tr align="center">
# <td>
# <span class="m-tcol-c list-count">4448269</span>
# </td>
# <td align="left" class="board-list">
# <span>
# <span class="aaa">
# <a class="m-tcol-c" href="/ArticleRead.nhn?clubid=15754634&amp;page=1&amp;menuid=2299&amp;boardtype=L&amp;articleid=4448269&amp;referrerAllArticles=false" onclick="return dynamicParamLink('/ArticleRead.nhn?clubid=15754634&amp;page=1&amp;menuid=2299&amp;boardtype=L&amp;articleid=4448269&amp;referrerAllArticles=false', event);" onmouseover="">[KUSEF] 마케팅 실무교육, 한국문화예술위원회 아창제 MCP 9기 (~10/24)</a>
# <input class="list-i-img" readonly="readonly" type="text"/>
# <input class="list-i-new" readonly="readonly" type="text"/>
# ...

# %%
    def parsing_headline(date):
        html=get_headline_page(date)
        element = web.Element(html)
#    print element


        a = html.findAll('div',{'class':'thumb'})
        for i in range(3):
            print 'Rank' + str(i+1) +': ' + str(a[i]).split('title=')[1].split('"')[1]

        for i in range(7):
            b = html.findAll('li',{'class':'gnum'+str(i+4)})
            print 'Rank' + str(i+4) +': ' + str(b[0]).split('title=')[1].split('"')[1]
   
        for i in range(10):
            c = html.findAll('li',{'class':'gnum'+str(i+11)})
            print 'Rank' + str(i+11) +': ' + str(c[0]).split('title=')[1].split('"')[1]

        for i in range(10):
            d = html.findAll('li',{'class':'gnum'+str(i+21)})
            print 'Rank' + str(i+21) +': ' + str(d[0]).split('title=')[1].split('"')[1]
